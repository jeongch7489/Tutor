# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# How many movies are in this data?

# %%
df[df['type'] == 'Movie'].count()
# Out:
# show_id         6131
# type            6131
# title           6131
# director        5943
# cast            5656
# country         5691
# date_added      6131
# release_year    6131
# rating          6129
# duration        6128
# listed_in       6131
# description     6131
# dtype: int64

# %% [markdown]
# How many different countries are there in the data? Find the top 5 countries with the most amount of movies and tv shows.

# %%
country = df['country'].unique()
len(country)

country = df.groupby(df['country']).count()
country.sort_values(by='show_id', ascending=False)
# Out:
#                                                     show_id  type  title  \
# country
# United States                                          2818  2818   2818
# India                                                   972   972    972
# United Kingdom                                          419   419    419
# Japan                                                   245   245    245
# South Korea                                             199   199    199
# ...                                                     ...   ...    ...
# Ireland, Canada, Luxembourg, United States, Uni...        1     1      1
# Ireland, Canada, United Kingdom, United States            1     1      1
# Ireland, Canada, United States, United Kingdom            1     1      1
# Ireland, France, Iceland, United States, Mexico...        1     1      1
# Zimbabwe                                                  1     1      1
#
#                                                     director  cast  \
# country
# ...

# %% [markdown]
# How many movies are in the data? How many TV shows are in the data?

# %%
movie = df[df['type'] == 'Movie']
tv_show = df[df['type'] == 'TV Show']

print(len(movie))
print(len(tv_show))
# Out:
# 6131
# 2676

# %% [markdown]
# How many TV shows does the South Korea have? How many movies does the United States have?

# %%
south_korea = df[df['country'] == 'South Korea']
US = df[df['country'] == 'United States']
(south_korea[south_korea['type'] == 'TV Show'].count())
US[US['type'] == 'Movie'].count()

movie.groupby('country').count().sort_values(by='show_id', ascending=False)
korea = tv_show.groupby('country').count().sort_values(by='show_id', ascending=False)

korea
korea[korea.index == 'South Korea']
# Out:
#              show_id  type  title  director  cast  date_added  release_year  \
# country
# South Korea      158   158    158        10   156         158           158
#
#              rating  duration  listed_in  description
# country
# South Korea     158       158        158          158

# %% [markdown]
# Using only one line of code, find the movie/tv show that was released the longest time ago. Which year was the movie released? What is the name of the movie/tv show?

# %%
df

# %%
longest_year = df[df['release_year'] == df['release_year'].unique().min()]
longest_year
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country         date_added  release_year rating  duration listed_in  \
# 4250     NaN  December 30, 2018          1925  TV-14  1 Season  TV Shows
#
#                                             description
# 4250  This collection restores films from women who ...

# %% [markdown]
# Create a new columns, num_cast, that will have the number of cast members.

# %%
df['cast']
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %%
df['num_cast'] = df['cast'].apply(lambda x: len(x.split(',')) if type(x) == str else x)
df.sort_values(by='num_cast', ascending=False)
# Out:
#      show_id     type                            title        director  \
# 3774   s3775  TV Show                     Black Mirror             NaN
# 1854   s1855  TV Show                  Social Distance             NaN
# 4220   s4221  TV Show           COMEDIANS of the world             NaN
# 1639   s1640  TV Show                  Heartbreak High             NaN
# 3449   s3450  TV Show                      Creeped Out             NaN
# ...      ...      ...                              ...             ...
# 8746   s8747    Movie                           Winnie  Pascale Lamche
# 8755   s8756  TV Show                Women Behind Bars             NaN
# 8756   s8757    Movie                        Woodstock   Barak Goodman
# 8763   s8764    Movie  WWII: Report from the Aleutians     John Huston
# 8803   s8804  TV Show                      Zombie Dumb             NaN
#
#                                                    cast  \
# 3774  Jesse Plemons, Cristin Milioti, Jimmi Simpson,...
# ...

# %%
len(df['cast'].values[1].split(','))
# Out:
# 19

# %%
df['cast'].values[1]
# Out:
# 'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng'

# %%
type(df['cast'].values[1])
# Out:
# str

# %% [markdown]
# What movie/tv show that has the most amount of cast listed?

# %%
df['num_cast'] = df['cast'].apply(lambda x: len(x.split(',')) if type(x) == str else x)
df.sort_values(by='num_cast', ascending=False)
# Out:
#      show_id     type                            title        director  \
# 3774   s3775  TV Show                     Black Mirror             NaN
# 1854   s1855  TV Show                  Social Distance             NaN
# 4220   s4221  TV Show           COMEDIANS of the world             NaN
# 1639   s1640  TV Show                  Heartbreak High             NaN
# 3449   s3450  TV Show                      Creeped Out             NaN
# ...      ...      ...                              ...             ...
# 8746   s8747    Movie                           Winnie  Pascale Lamche
# 8755   s8756  TV Show                Women Behind Bars             NaN
# 8756   s8757    Movie                        Woodstock   Barak Goodman
# 8763   s8764    Movie  WWII: Report from the Aleutians     John Huston
# 8803   s8804  TV Show                      Zombie Dumb             NaN
#
#                                                    cast  \
# 3774  Jesse Plemons, Cristin Milioti, Jimmi Simpson,...
# ...

# %%
df['cast_list'] =  df['cast'].apply(lambda x: x.strip('').split(', ') if type(x) == str else x)
df['cast_list']
# Out:
# 0                                                     NaN
# 1       [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...
# 2       [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...
# 3                                                     NaN
# 4       [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...
#                               ...
# 8802    [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...
# 8803                                                  NaN
# 8804    [Jesse Eisenberg, Woody Harrelson, Emma Stone,...
# 8805    [Tim Allen, Courteney Cox, Chevy Chase, Kate M...
# 8806    [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...
# Name: cast_list, Length: 8807, dtype: object

# %%
df['cast_list'][1]
# Out:
# ['Ama Qamata',
#  'Khosi Ngema',
#  'Gail Mabalane',
#  'Thabang Molaba',
#  'Dillon Windvogel',
#  'Natasha Thahane',
#  'Arno Greeff',
#  'Xolile Tshabalala',
#  'Getmore Sithole',
#  'Cindy Mahlangu',
#  'Ryle De Morny',
#  'Greteli Fincham',
#  'Sello Maake Ka-Ncube',
#  'Odwa Gwanya',
#  'Mekaila Mathys',
#  'Sandi Schultz',
#  'Duane Williams',
#  'Shamilla Miller',
#  'Patrick Mofokeng']

# %% [markdown]
# Find the total number of movies/tv shows where Jake Gyllenhaal is a part of the cast.

# %%
count = 0
for i in range(len(df)):
    if type(df['cast_list'][i]) == list:
        if 'Jake Gyllenhaal' in df['cast_list'][i]:
            count += 1
count
# Out:
# 9

# %%
df['country'][1]

# %% [markdown]
# Find the name of the movies that Amy Adams is in.

# %%
for i in range(len(df)):
    if type(df['cast_list'][i]) == list:
        if 'Amy Adams' in df['cast_list'][i]:
            print(df['title'][i])
# Out:
# Catch Me If You Can
# Talladega Nights: The Ballad of Ricky Bobby
# The Woman in the Window
# The Master
# Nocturnal Animals
# Hillbilly Elegy
# Doubt
# Her
# Julie & Julia
# Junebug
# Leap Year
# The Fighter
# The Muppets

# %% [markdown]
# Homework

# %% [markdown]
# There seems to be a lot of missing data values in this data. What is the total amount of missing data for EACH column?

# %%
count = 0
for i in range(len(df)):
    if type(df['country'][i]) == float:
        count += 1
count
# Out:
# 831

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# num_cast         825
# cast_list        825
# dtype: int64

# %% [markdown]
# First, lets deal with the columns that have manageable number of missing data values.
#
# Which movies are missing the ratings values? add_ratings is a list of the missing rating values in order. Fill in the missing values of ratings with the provided list.

# %%
add_ratings = ['PG-13', 'TV-14', 'TV-MA', 'PG-13']

# %%
df.loc[df['rating'].isna(), 'rating'] = add_ratings

# %%
df.loc[df['rating'].isna(), 'rating']
# Out:
# Series([], Name: rating, dtype: object)

# %% [markdown]
# Now do the same for the data mising duration. What is different about this? Fix the error.

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', nan, 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.loc[df['duration'].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, num_cast, cast_list]
# Index: []

# %%
df['rating'] = df['rating'].apply(lambda x: np.nan if 'min' in x else x)

# %%
df.loc[df['rating'].isna(), 'rating']
# Out:
# 5541    NaN
# 5794    NaN
# 5813    NaN
# Name: rating, dtype: object

# %% [markdown]
# The 'listed_in' column contains data that specifies the genre the movie/tv show is classified as.
# Create a dictionary that has each unique genre as the key and the count of movies that are associated with the genre as the value.

# %%
df = df.rename(columns={'listed_in': 'genre'})

# %%
df.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration          genre  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  num_cast cast_list
# 0  As her father nears the end of his life, filmm...       NaN       NaN

# %%
genre_dict = {}

for k, v in enumerate(new_genre):
    if v not in genre_dict.keys():
        genre_dict.update({v: 1})
    else:
        genre_dict[v] += 1
        
    
genre_dicts
# Out:
# {'Documentaries': 869,
#  'InternationalTVShows': 1351,
#  'TVDramas': 763,
#  'TVMysteries': 98,
#  'CrimeTVShows': 470,
#  'TVAction&Adventure': 168,
#  'Docuseries': 395,
#  'RealityTV': 255,
#  'RomanticTVShows': 370,
#  'TVComedies': 581,
#  'TVHorror': 75,
#  'Children&FamilyMovies': 641,
#  'Dramas': 2427,
#  'IndependentMovies': 756,
#  'InternationalMovies': 2752,
#  'BritishTVShows': 253,
#  'Comedies': 1674,
#  'Spanish-LanguageTVShows': 174,
#  'Thrillers': 577,
#  'RomanticMovies': 616,
#  'Music&Musicals': 375,
#  'HorrorMovies': 357,
#  'Sci-Fi&Fantasy': 243,
#  'TVThrillers': 57,
#  "Kids'TV": 451,
#  'Action&Adventure': 859,
#  'TVSci-Fi&Fantasy': 84,
#  'ClassicMovies': 116,
#  'AnimeFeatures': 71,
#  'SportsMovies': 219,
#  'AnimeSeries': 176,
#  'KoreanTVShows': 151,
#  'Science&NatureTV': 92,
#  'TeenTVShows': 69,
#  'CultMovies': 71,
#  'TVShows': 16,
#  'Faith&Spirituality': 65,
#  'LGBTQMovies': 102,
#  'Stand-UpComedy': 343,
#  'Movies': 57,
# ...

# %%
new_genre = [x for xs in genre_list for x in xs.split(',')]

# %%
new_genre = [x.replace(' ', '') for x in new_genre]

# %%
for k, v in enumerate(new_genre):
    print(k, v)
# Out:
# 0 Documentaries
# 1 InternationalTVShows
# 2 TVDramas
# 3 TVMysteries
# 4 CrimeTVShows
# 5 InternationalTVShows
# 6 TVAction&Adventure
# 7 Docuseries
# 8 RealityTV
# 9 InternationalTVShows
# 10 RomanticTVShows
# 11 TVComedies
# 12 TVDramas
# 13 TVHorror
# 14 TVMysteries
# 15 Children&FamilyMovies
# 16 Dramas
# 17 IndependentMovies
# 18 InternationalMovies
# 19 BritishTVShows
# 20 RealityTV
# 21 Comedies
# 22 Dramas
# 23 CrimeTVShows
# 24 Docuseries
# 25 InternationalTVShows
# 26 CrimeTVShows
# 27 InternationalTVShows
# 28 TVAction&Adventure
# 29 Dramas
# 30 InternationalMovies
# 31 Children&FamilyMovies
# 32 Comedies
# 33 BritishTVShows
# 34 CrimeTVShows
# 35 Docuseries
# 36 TVComedies
# 37 TVDramas
# 38 Documentaries
# 39 InternationalMovies
# 40 CrimeTVShows
# 41 Spanish-LanguageTVShows
# 42 TVDramas
# 43 Thrillers
# 44 InternationalTVShows
# 45 Spanish-LanguageTVShows
# 46 TVAction&Adventure
# 47 CrimeTVShows
# 48 Docuseries
# 49 InternationalTVShows
# 50 InternationalTVShows
# ...
